# %%
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
import dataloader as dl

# %% [markdown]
# Configration

# %%
Learning_rate = 0.01
no_epochs = 30

# %% [markdown]
# # Logistic Regression Implementation

# %%
torch.manual_seed(42)

class Logistic_Regression_from_scratch():
    def __init__(self):
        self.w = torch.randn(28*28, requires_grad=True)

        self.b = torch.zeros(1, requires_grad=True)

        self.validation_losses = []
        self.training_losses = []
        self.validation_accuracies = []
        self.training_accuracies = []

    def sigmoid(self, z):
        return 1 / (1 + torch.exp(-z))

    def bce_loss(self,y_true, y_pred):
        epsilon = 1e-7
        loss = - (y_true * torch.log(y_pred + epsilon) + (1 - y_true) * torch.log(1 - y_pred + epsilon))
        return torch.mean(loss)

    def forward_pass(self, x):
        output =  x @ self.w + self.b
        y_pred = self.sigmoid(output)
        return y_pred

    def train(self, learning_rate, no_epochs, train_loader, val_loader):
        for epoch in range(no_epochs):
            train_loss = 0
            val_losses = 0
            train_accuracy = 0
            val_accuracy = 0

            for data, target in train_loader:
                target = target.float()

                y_pred = self.forward_pass(data)
                loss = self.bce_loss(target, y_pred)


                train_accuracy += self.calculate_accuracy(target, y_pred)

                train_loss += loss.item()

                loss.backward()

                with torch.no_grad():
                    self.w -= learning_rate * self.w.grad
                    self.b  -= learning_rate * self.b.grad

                    self.w.grad.zero_()
                    self.b.grad.zero_()



            with torch.no_grad():
                for val_data, val_target in val_loader:
                    val_target = val_target.float()
                    val_pred = self.forward_pass(val_data)

                    val_accuracy += self.calculate_accuracy(val_target, val_pred)

                    val_loss = self.bce_loss(val_target, val_pred)
                    val_losses += val_loss.item()


            self.training_accuracies.append(train_accuracy / len(train_loader))
            self.validation_accuracies.append(val_accuracy / len(val_loader))
            avg_train_loss = train_loss / len(train_loader)
            avg_val_loss = val_losses / len(val_loader)


            self.training_losses.append(avg_train_loss)
            self.validation_losses.append(avg_val_loss)

            print(f'Epoch {epoch+1}/{no_epochs}')
            print(f'  Train Loss: {avg_train_loss:.4f} | Train Acc: {self.training_accuracies[epoch]:.2f}%')
            print(f'  Val Loss: {avg_val_loss:.4f} | Val Acc: {self.validation_accuracies[epoch]:.2f}%')



    def predict(self, x):
        with torch.no_grad():
            y_pred = self.forward_pass(x)
            predicted_labels = (y_pred > 0.5).float()
        return predicted_labels

    def calculate_accuracy(self, y_true, y_pred):
        predicted_labels = (y_pred > 0.5).float()
        return (predicted_labels == y_true).sum().item() / y_true.shape[0] *100

# %%
logisticRegression = Logistic_Regression_from_scratch()
loader=dl.build_loader(64)
logisticRegression.train(Learning_rate, no_epochs, loader['train_loader_linear_filtered'], loader['val_loader_linear_filtered'])
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 591kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.61MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 13.3MB/s]
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 2.0716 | Train Acc: 56.86%
#   Val Loss: 0.6116 | Val Acc: 78.48%
# Epoch 2/30
#   Train Loss: 0.4199 | Train Acc: 85.72%
#   Val Loss: 0.2864 | Val Acc: 91.34%
# Epoch 3/30
#   Train Loss: 0.2276 | Train Acc: 92.35%
#   Val Loss: 0.1834 | Val Acc: 94.57%
# Epoch 4/30
#   Train Loss: 0.1533 | Train Acc: 95.10%
#   Val Loss: 0.1338 | Val Acc: 95.86%
# Epoch 5/30
#   Train Loss: 0.1147 | Train Acc: 96.44%
#   Val Loss: 0.1054 | Val Acc: 96.96%
# Epoch 6/30
#   Train Loss: 0.0920 | Train Acc: 97.22%
#   Val Loss: 0.0875 | Val Acc: 97.50%
# Epoch 7/30
#   Train Loss: 0.0773 | Train Acc: 97.67%
#   Val Loss: 0.0752 | Val Acc: 97.96%
# Epoch 8/30
#   Train Loss: 0.0666 | Train Acc: 98.02%
#   Val Loss: 0.0663 | Val Acc: 98.34%
# Epoch 9/30
#   Train Loss: 0.0591 | Train Acc: 98.31%
#   Val Loss: 0.0595 | Val Acc: 98.53%
# Epoch 10/30
#   Train Loss: 0.0533 | Train Acc: 98.51%
#   Val Loss: 0.0543 | Val Acc: 98.60%
# Epoch 11/30
#   Train Loss: 0.0485 | Train Acc: 98.63%
#   Val Loss: 0.0500 | Val Acc: 98.64%
# Epoch 12/30
#   Train Loss: 0.0448 | Train Acc: 98.74%
#   Val Loss: 0.0465 | Val Acc: 98.80%
# Epoch 13/30
#   Train Loss: 0.0417 | Train Acc: 98.80%
#   Val Loss: 0.0435 | Val Acc: 98.88%
# Epoch 14/30
#   Train Loss: 0.0391 | Train Acc: 98.90%
#   Val Loss: 0.0410 | Val Acc: 98.88%
# Epoch 15/30
#   Train Loss: 0.0369 | Train Acc: 98.99%
#   Val Loss: 0.0389 | Val Acc: 98.91%
# Epoch 16/30
#   Train Loss: 0.0351 | Train Acc: 99.00%
#   Val Loss: 0.0371 | Val Acc: 98.95%
# Epoch 17/30
#   Train Loss: 0.0333 | Train Acc: 99.04%
#   Val Loss: 0.0354 | Val Acc: 98.95%
# Epoch 18/30
#   Train Loss: 0.0319 | Train Acc: 99.13%
#   Val Loss: 0.0340 | Val Acc: 98.95%
# Epoch 19/30
#   Train Loss: 0.0308 | Train Acc: 99.18%
#   Val Loss: 0.0328 | Val Acc: 98.99%
# Epoch 20/30
#   Train Loss: 0.0294 | Train Acc: 99.21%
#   Val Loss: 0.0316 | Val Acc: 99.07%
# Epoch 21/30
#   Train Loss: 0.0284 | Train Acc: 99.24%
#   Val Loss: 0.0306 | Val Acc: 99.15%
# Epoch 22/30
#   Train Loss: 0.0276 | Train Acc: 99.27%
#   Val Loss: 0.0297 | Val Acc: 99.19%
# Epoch 23/30
#   Train Loss: 0.0266 | Train Acc: 99.30%
#   Val Loss: 0.0289 | Val Acc: 99.27%
# Epoch 24/30
#   Train Loss: 0.0259 | Train Acc: 99.30%
#   Val Loss: 0.0282 | Val Acc: 99.34%
# Epoch 25/30
#   Train Loss: 0.0252 | Train Acc: 99.32%
#   Val Loss: 0.0275 | Val Acc: 99.34%
# Epoch 26/30
#   Train Loss: 0.0245 | Train Acc: 99.33%
#   Val Loss: 0.0269 | Val Acc: 99.38%
# Epoch 27/30
#   Train Loss: 0.0239 | Train Acc: 99.36%
#   Val Loss: 0.0263 | Val Acc: 99.38%
# Epoch 28/30
#   Train Loss: 0.0233 | Train Acc: 99.36%
#   Val Loss: 0.0258 | Val Acc: 99.38%
# Epoch 29/30
#   Train Loss: 0.0228 | Train Acc: 99.36%
#   Val Loss: 0.0253 | Val Acc: 99.38%
# Epoch 30/30
#   Train Loss: 0.0223 | Train Acc: 99.37%
#   Val Loss: 0.0248 | Val Acc: 99.41%

# %% [markdown]
# ## Training vs Validation Loss

# %%
def plot_loss(text):
    plt.figure(figsize=(10, 6))
    plt.plot(logisticRegression.training_losses, label='Training Loss')
    plt.plot(logisticRegression.validation_losses, label='Validation Loss')
    plt.xlabel(f"Epoch {text}")
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()
plot_loss('')

# %% [markdown]
# ## Target vs value accuracy

# %%
def plot_acc(text):
    plt.figure(figsize=(8, 5))
    plt.plot(logisticRegression.training_accuracies, label='Training accuracy')
    plt.plot(logisticRegression.validation_accuracies, label='Validation accuracy')
    plt.xlabel(f"Epoch {text}")
    plt.ylabel('Accuracy (%)')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
plot_acc('')

# %% [markdown]
# ### Learing curve with error bars

# %%
window = 3
train_std = [np.std(logisticRegression.training_losses[max(0,i-window):i+1]) for i in range(len(logisticRegression.training_losses))]
val_std = [np.std(logisticRegression.validation_losses[max(0,i-window):i+1]) for i in range(len(logisticRegression.validation_losses))]

plt.figure(figsize=(10, 6))
plt.errorbar(range(len(logisticRegression.training_losses)), logisticRegression.training_losses, yerr=train_std, label='Train Loss', capsize=3)
plt.errorbar(range(len(logisticRegression.validation_losses)), logisticRegression.validation_losses, yerr=val_std, label='Val Loss', capsize=3)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Learning Curves with Error Bars')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### converge Analysis

# %%
def plot_converge(text):
    train_change = [0] + [logisticRegression.training_losses[i] - logisticRegression.training_losses[i-1] for i in range(1, len(logisticRegression.training_losses))]
    val_change = [0] + [logisticRegression.validation_losses[i] - logisticRegression.validation_losses[i-1] for i in range(1, len(logisticRegression.validation_losses))]

    plt.figure(figsize=(10, 6))
    plt.plot(train_change, label='Train Loss Change')
    plt.plot(val_change, label='Val Loss Change')
    plt.axhline(y=0, color='black', linestyle='--')
    plt.xlabel(f"Epoch {text}")
    plt.ylabel('Loss Change')
    plt.title('Convergence Analysis')
    plt.legend()
    plt.grid(True)
    plt.show()
plot_converge('')

# %% [markdown]
# ## Test the Model

# %%
def test_model():
    accuracy = 0
    targets = []
    predictions = []
    with torch.no_grad():
        for data, target in loader["test_loader_linear_filtered"]:
            target = target.float()

            prediction = logisticRegression.predict(data)
            accuracy += logisticRegression.calculate_accuracy(target, prediction)
            targets.extend(target.numpy())
            predictions.extend(prediction)

    test_accuracy = accuracy / len(loader["test_loader_linear_filtered"])

    print(f"Average Test Accuracy over all batches: {test_accuracy:.2f}%")

    matrix = confusion_matrix(np.array(targets), np.array(predictions))
    print("Confusion Matrix:")
    print(matrix)
test_model();
# Out:
# Average Test Accuracy over all batches: 99.26%
# Confusion Matrix:
# [[1169   16]
#  [   3 1346]]

# %% [markdown]
# ## Define hyperparameters

# %%
learning_rates = [0.001,0.01,0.1,1]
batch_sizes = [16,32,64,128]

# %%
results_lr = []
fixed_batch_size = 64
print("Testing different learning rates with fixed batch size (64):")
best_val_accuracy_lr = 0
best_lr=None

for lr in learning_rates:
    print(f"Training with Learning Rate: {lr}, Batch Size: {fixed_batch_size}")

    logisticRegression = Logistic_Regression_from_scratch()
    loader = dl.build_loader(fixed_batch_size)

    logisticRegression.train(lr, no_epochs, loader['train_loader_linear_filtered'], loader['val_loader_linear_filtered'])
    plot_acc(f'with learning rate of {lr}')
    plot_loss(f'with learning rate of {lr}')
    plot_converge(f'with learning rate of {lr}')

    current_best_val_accuracy = max(logisticRegression.validation_accuracies)
    if current_best_val_accuracy > best_val_accuracy_lr:
        best_val_accuracy_lr = current_best_val_accuracy
        best_lr=lr
# Out:
# Testing different learning rates with fixed batch size (64):
# Training with Learning Rate: 0.001, Batch Size: 64
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 0.7630 | Train Acc: 85.91%
#   Val Loss: 0.6897 | Val Acc: 86.05%
# Epoch 2/30
#   Train Loss: 0.6368 | Train Acc: 87.43%
#   Val Loss: 0.5771 | Val Acc: 87.92%
# Epoch 3/30
#   Train Loss: 0.5397 | Train Acc: 88.64%
#   Val Loss: 0.4908 | Val Acc: 89.05%
# Epoch 4/30
#   Train Loss: 0.4654 | Train Acc: 89.84%
#   Val Loss: 0.4239 | Val Acc: 90.34%
# Epoch 5/30
#   Train Loss: 0.4050 | Train Acc: 90.68%
#   Val Loss: 0.3711 | Val Acc: 91.24%
# Epoch 6/30
#   Train Loss: 0.3585 | Train Acc: 91.57%
#   Val Loss: 0.3294 | Val Acc: 91.98%
# Epoch 7/30
#   Train Loss: 0.3201 | Train Acc: 92.18%
#   Val Loss: 0.2962 | Val Acc: 92.71%
# Epoch 8/30
#   Train Loss: 0.2885 | Train Acc: 92.66%
#   Val Loss: 0.2691 | Val Acc: 93.45%
# Epoch 9/30
#   Train Loss: 0.2630 | Train Acc: 93.32%
#   Val Loss: 0.2472 | Val Acc: 93.96%
# Epoch 10/30
#   Train Loss: 0.2415 | Train Acc: 93.74%
#   Val Loss: 0.2289 | Val Acc: 94.39%
# Epoch 11/30
#   Train Loss: 0.2235 | Train Acc: 94.04%
#   Val Loss: 0.2137 | Val Acc: 94.74%
# Epoch 12/30
#   Train Loss: 0.2080 | Train Acc: 94.34%
#   Val Loss: 0.2008 | Val Acc: 95.21%
# Epoch 13/30
#   Train Loss: 0.1953 | Train Acc: 94.67%
#   Val Loss: 0.1898 | Val Acc: 95.49%
# Epoch 14/30
#   Train Loss: 0.1849 | Train Acc: 94.99%
#   Val Loss: 0.1803 | Val Acc: 95.64%
# Epoch 15/30
#   Train Loss: 0.1737 | Train Acc: 95.16%
#   Val Loss: 0.1721 | Val Acc: 95.88%
# Epoch 16/30
#   Train Loss: 0.1651 | Train Acc: 95.40%
#   Val Loss: 0.1649 | Val Acc: 96.11%
# Epoch 17/30
#   Train Loss: 0.1576 | Train Acc: 95.68%
#   Val Loss: 0.1586 | Val Acc: 96.15%
# Epoch 18/30
#   Train Loss: 0.1507 | Train Acc: 95.74%
#   Val Loss: 0.1529 | Val Acc: 96.31%
# Epoch 19/30
#   Train Loss: 0.1450 | Train Acc: 95.85%
#   Val Loss: 0.1479 | Val Acc: 96.50%
# Epoch 20/30
#   Train Loss: 0.1393 | Train Acc: 96.01%
#   Val Loss: 0.1434 | Val Acc: 96.62%
# Epoch 21/30
#   Train Loss: 0.1345 | Train Acc: 96.10%
#   Val Loss: 0.1393 | Val Acc: 96.78%
# Epoch 22/30
#   Train Loss: 0.1296 | Train Acc: 96.17%
#   Val Loss: 0.1355 | Val Acc: 96.89%
# Epoch 23/30
#   Train Loss: 0.1261 | Train Acc: 96.22%
#   Val Loss: 0.1320 | Val Acc: 96.89%
# Epoch 24/30
#   Train Loss: 0.1220 | Train Acc: 96.34%
#   Val Loss: 0.1289 | Val Acc: 96.93%
# Epoch 25/30
#   Train Loss: 0.1184 | Train Acc: 96.38%
#   Val Loss: 0.1260 | Val Acc: 96.93%
# Epoch 26/30
#   Train Loss: 0.1152 | Train Acc: 96.47%
#   Val Loss: 0.1233 | Val Acc: 96.97%
# Epoch 27/30
#   Train Loss: 0.1126 | Train Acc: 96.54%
#   Val Loss: 0.1207 | Val Acc: 97.16%
# Epoch 28/30
#   Train Loss: 0.1096 | Train Acc: 96.62%
#   Val Loss: 0.1184 | Val Acc: 97.16%
# Epoch 29/30
#   Train Loss: 0.1070 | Train Acc: 96.73%
#   Val Loss: 0.1161 | Val Acc: 97.16%
# Epoch 30/30
#   Train Loss: 0.1050 | Train Acc: 96.78%
#   Val Loss: 0.1141 | Val Acc: 97.12%
# Training with Learning Rate: 0.01, Batch Size: 64
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 0.2446 | Train Acc: 92.52%
#   Val Loss: 0.1761 | Val Acc: 94.51%
# Epoch 2/30
#   Train Loss: 0.1604 | Train Acc: 95.02%
#   Val Loss: 0.1251 | Val Acc: 95.76%
# Epoch 3/30
#   Train Loss: 0.1206 | Train Acc: 96.30%
#   Val Loss: 0.0981 | Val Acc: 96.79%
# Epoch 4/30
#   Train Loss: 0.0990 | Train Acc: 96.93%
#   Val Loss: 0.0814 | Val Acc: 97.25%
# Epoch 5/30
#   Train Loss: 0.0837 | Train Acc: 97.37%
#   Val Loss: 0.0701 | Val Acc: 97.60%
# Epoch 6/30
#   Train Loss: 0.0735 | Train Acc: 97.74%
#   Val Loss: 0.0621 | Val Acc: 98.03%
# Epoch 7/30
#   Train Loss: 0.0660 | Train Acc: 97.98%
#   Val Loss: 0.0561 | Val Acc: 98.23%
# Epoch 8/30
#   Train Loss: 0.0602 | Train Acc: 98.21%
#   Val Loss: 0.0515 | Val Acc: 98.35%
# Epoch 9/30
#   Train Loss: 0.0557 | Train Acc: 98.32%
#   Val Loss: 0.0478 | Val Acc: 98.49%
# Epoch 10/30
#   Train Loss: 0.0521 | Train Acc: 98.38%
#   Val Loss: 0.0447 | Val Acc: 98.49%
# Epoch 11/30
#   Train Loss: 0.0490 | Train Acc: 98.58%
#   Val Loss: 0.0422 | Val Acc: 98.68%
# Epoch 12/30
#   Train Loss: 0.0459 | Train Acc: 98.67%
#   Val Loss: 0.0400 | Val Acc: 98.68%
# Epoch 13/30
#   Train Loss: 0.0436 | Train Acc: 98.78%
#   Val Loss: 0.0381 | Val Acc: 98.68%
# Epoch 14/30
#   Train Loss: 0.0417 | Train Acc: 98.84%
#   Val Loss: 0.0365 | Val Acc: 98.76%
# Epoch 15/30
#   Train Loss: 0.0399 | Train Acc: 98.86%
#   Val Loss: 0.0350 | Val Acc: 98.80%
# Epoch 16/30
#   Train Loss: 0.0383 | Train Acc: 98.87%
#   Val Loss: 0.0337 | Val Acc: 98.84%
# Epoch 17/30
#   Train Loss: 0.0368 | Train Acc: 98.88%
#   Val Loss: 0.0325 | Val Acc: 98.84%
# Epoch 18/30
#   Train Loss: 0.0357 | Train Acc: 98.94%
#   Val Loss: 0.0314 | Val Acc: 98.84%
# Epoch 19/30
#   Train Loss: 0.0346 | Train Acc: 98.98%
#   Val Loss: 0.0305 | Val Acc: 98.88%
# Epoch 20/30
#   Train Loss: 0.0335 | Train Acc: 99.02%
#   Val Loss: 0.0296 | Val Acc: 98.88%
# Epoch 21/30
#   Train Loss: 0.0323 | Train Acc: 99.05%
#   Val Loss: 0.0287 | Val Acc: 98.91%
# Epoch 22/30
#   Train Loss: 0.0316 | Train Acc: 99.08%
#   Val Loss: 0.0279 | Val Acc: 98.91%
# Epoch 23/30
#   Train Loss: 0.0306 | Train Acc: 99.08%
#   Val Loss: 0.0272 | Val Acc: 98.95%
# Epoch 24/30
#   Train Loss: 0.0298 | Train Acc: 99.12%
#   Val Loss: 0.0265 | Val Acc: 98.95%
# Epoch 25/30
#   Train Loss: 0.0291 | Train Acc: 99.13%
#   Val Loss: 0.0259 | Val Acc: 98.99%
# Epoch 26/30
#   Train Loss: 0.0283 | Train Acc: 99.13%
#   Val Loss: 0.0253 | Val Acc: 98.99%
# Epoch 27/30
#   Train Loss: 0.0279 | Train Acc: 99.14%
#   Val Loss: 0.0247 | Val Acc: 98.99%
# Epoch 28/30
#   Train Loss: 0.0271 | Train Acc: 99.15%
#   Val Loss: 0.0242 | Val Acc: 98.99%
# Epoch 29/30
#   Train Loss: 0.0265 | Train Acc: 99.15%
#   Val Loss: 0.0237 | Val Acc: 99.03%
# Epoch 30/30
#   Train Loss: 0.0260 | Train Acc: 99.15%
#   Val Loss: 0.0232 | Val Acc: 99.10%
# Training with Learning Rate: 0.1, Batch Size: 64
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 0.2110 | Train Acc: 93.09%
#   Val Loss: 0.0606 | Val Acc: 98.17%
# Epoch 2/30
#   Train Loss: 0.0472 | Train Acc: 98.82%
#   Val Loss: 0.0329 | Val Acc: 99.22%
# Epoch 3/30
#   Train Loss: 0.0308 | Train Acc: 99.20%
#   Val Loss: 0.0245 | Val Acc: 99.22%
# Epoch 4/30
#   Train Loss: 0.0237 | Train Acc: 99.37%
#   Val Loss: 0.0201 | Val Acc: 99.26%
# Epoch 5/30
#   Train Loss: 0.0196 | Train Acc: 99.51%
#   Val Loss: 0.0173 | Val Acc: 99.34%
# Epoch 6/30
#   Train Loss: 0.0172 | Train Acc: 99.59%
#   Val Loss: 0.0155 | Val Acc: 99.41%
# Epoch 7/30
#   Train Loss: 0.0154 | Train Acc: 99.65%
#   Val Loss: 0.0146 | Val Acc: 99.45%
# Epoch 8/30
#   Train Loss: 0.0141 | Train Acc: 99.67%
#   Val Loss: 0.0138 | Val Acc: 99.49%
# Epoch 9/30
#   Train Loss: 0.0132 | Train Acc: 99.69%
#   Val Loss: 0.0133 | Val Acc: 99.53%
# Epoch 10/30
#   Train Loss: 0.0124 | Train Acc: 99.69%
#   Val Loss: 0.0127 | Val Acc: 99.57%
# Epoch 11/30
#   Train Loss: 0.0117 | Train Acc: 99.71%
#   Val Loss: 0.0122 | Val Acc: 99.57%
# Epoch 12/30
#   Train Loss: 0.0112 | Train Acc: 99.75%
#   Val Loss: 0.0119 | Val Acc: 99.61%
# Epoch 13/30
#   Train Loss: 0.0108 | Train Acc: 99.75%
#   Val Loss: 0.0117 | Val Acc: 99.65%
# Epoch 14/30
#   Train Loss: 0.0104 | Train Acc: 99.75%
#   Val Loss: 0.0113 | Val Acc: 99.65%
# Epoch 15/30
#   Train Loss: 0.0101 | Train Acc: 99.75%
#   Val Loss: 0.0110 | Val Acc: 99.65%
# Epoch 16/30
#   Train Loss: 0.0101 | Train Acc: 99.79%
#   Val Loss: 0.0107 | Val Acc: 99.65%
# Epoch 17/30
#   Train Loss: 0.0096 | Train Acc: 99.79%
#   Val Loss: 0.0107 | Val Acc: 99.69%
# Epoch 18/30
#   Train Loss: 0.0094 | Train Acc: 99.80%
#   Val Loss: 0.0105 | Val Acc: 99.69%
# Epoch 19/30
#   Train Loss: 0.0092 | Train Acc: 99.79%
#   Val Loss: 0.0104 | Val Acc: 99.69%
# Epoch 20/30
#   Train Loss: 0.0090 | Train Acc: 99.79%
#   Val Loss: 0.0103 | Val Acc: 99.69%
# Epoch 21/30
#   Train Loss: 0.0090 | Train Acc: 99.79%
#   Val Loss: 0.0102 | Val Acc: 99.69%
# Epoch 22/30
#   Train Loss: 0.0086 | Train Acc: 99.79%
#   Val Loss: 0.0101 | Val Acc: 99.69%
# Epoch 23/30
#   Train Loss: 0.0085 | Train Acc: 99.80%
#   Val Loss: 0.0101 | Val Acc: 99.69%
# Epoch 24/30
#   Train Loss: 0.0083 | Train Acc: 99.80%
#   Val Loss: 0.0099 | Val Acc: 99.73%
# Epoch 25/30
#   Train Loss: 0.0082 | Train Acc: 99.80%
#   Val Loss: 0.0098 | Val Acc: 99.73%
# Epoch 26/30
#   Train Loss: 0.0081 | Train Acc: 99.82%
#   Val Loss: 0.0097 | Val Acc: 99.73%
# Epoch 27/30
#   Train Loss: 0.0079 | Train Acc: 99.80%
#   Val Loss: 0.0096 | Val Acc: 99.73%
# Epoch 28/30
#   Train Loss: 0.0078 | Train Acc: 99.82%
#   Val Loss: 0.0096 | Val Acc: 99.73%
# Epoch 29/30
#   Train Loss: 0.0077 | Train Acc: 99.80%
#   Val Loss: 0.0095 | Val Acc: 99.73%
# Epoch 30/30
#   Train Loss: 0.0076 | Train Acc: 99.82%
#   Val Loss: 0.0094 | Val Acc: 99.73%
# Training with Learning Rate: 1, Batch Size: 64
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 0.0585 | Train Acc: 98.35%
#   Val Loss: 0.0240 | Val Acc: 99.34%
# Epoch 2/30
#   Train Loss: 0.0149 | Train Acc: 99.58%
#   Val Loss: 0.0163 | Val Acc: 99.49%
# Epoch 3/30
#   Train Loss: 0.0106 | Train Acc: 99.74%
#   Val Loss: 0.0149 | Val Acc: 99.53%
# Epoch 4/30
#   Train Loss: 0.0087 | Train Acc: 99.77%
#   Val Loss: 0.0146 | Val Acc: 99.57%
# Epoch 5/30
#   Train Loss: 0.0076 | Train Acc: 99.76%
#   Val Loss: 0.0124 | Val Acc: 99.61%
# Epoch 6/30
#   Train Loss: 0.0065 | Train Acc: 99.82%
#   Val Loss: 0.0138 | Val Acc: 99.61%
# Epoch 7/30
#   Train Loss: 0.0061 | Train Acc: 99.88%
#   Val Loss: 0.0116 | Val Acc: 99.57%
# Epoch 8/30
#   Train Loss: 0.0054 | Train Acc: 99.84%
#   Val Loss: 0.0114 | Val Acc: 99.57%
# Epoch 9/30
#   Train Loss: 0.0050 | Train Acc: 99.86%
#   Val Loss: 0.0119 | Val Acc: 99.57%
# Epoch 10/30
#   Train Loss: 0.0048 | Train Acc: 99.88%
#   Val Loss: 0.0107 | Val Acc: 99.57%
# Epoch 11/30
#   Train Loss: 0.0041 | Train Acc: 99.88%
#   Val Loss: 0.0120 | Val Acc: 99.57%
# Epoch 12/30
#   Train Loss: 0.0039 | Train Acc: 99.91%
#   Val Loss: 0.0111 | Val Acc: 99.57%
# Epoch 13/30
#   Train Loss: 0.0036 | Train Acc: 99.91%
#   Val Loss: 0.0102 | Val Acc: 99.65%
# Epoch 14/30
#   Train Loss: 0.0034 | Train Acc: 99.89%
#   Val Loss: 0.0103 | Val Acc: 99.65%
# Epoch 15/30
#   Train Loss: 0.0031 | Train Acc: 99.91%
#   Val Loss: 0.0118 | Val Acc: 99.57%
# Epoch 16/30
#   Train Loss: 0.0030 | Train Acc: 99.89%
#   Val Loss: 0.0106 | Val Acc: 99.65%
# Epoch 17/30
#   Train Loss: 0.0029 | Train Acc: 99.92%
#   Val Loss: 0.0105 | Val Acc: 99.65%
# Epoch 18/30
#   Train Loss: 0.0026 | Train Acc: 99.92%
#   Val Loss: 0.0104 | Val Acc: 99.65%
# Epoch 19/30
#   Train Loss: 0.0025 | Train Acc: 99.92%
#   Val Loss: 0.0102 | Val Acc: 99.65%
# Epoch 20/30
#   Train Loss: 0.0022 | Train Acc: 99.91%
#   Val Loss: 0.0117 | Val Acc: 99.57%
# Epoch 21/30
#   Train Loss: 0.0022 | Train Acc: 99.93%
#   Val Loss: 0.0096 | Val Acc: 99.69%
# Epoch 22/30
#   Train Loss: 0.0020 | Train Acc: 99.93%
#   Val Loss: 0.0094 | Val Acc: 99.77%
# Epoch 23/30
#   Train Loss: 0.0020 | Train Acc: 99.93%
#   Val Loss: 0.0101 | Val Acc: 99.65%
# Epoch 24/30
#   Train Loss: 0.0019 | Train Acc: 99.95%
#   Val Loss: 0.0102 | Val Acc: 99.65%
# Epoch 25/30
#   Train Loss: 0.0018 | Train Acc: 99.95%
#   Val Loss: 0.0107 | Val Acc: 99.65%
# Epoch 26/30
#   Train Loss: 0.0017 | Train Acc: 99.93%
#   Val Loss: 0.0101 | Val Acc: 99.65%
# Epoch 27/30
#   Train Loss: 0.0016 | Train Acc: 99.96%
#   Val Loss: 0.0099 | Val Acc: 99.65%
# Epoch 28/30
#   Train Loss: 0.0015 | Train Acc: 99.96%
#   Val Loss: 0.0106 | Val Acc: 99.65%
# Epoch 29/30
#   Train Loss: 0.0014 | Train Acc: 99.96%
#   Val Loss: 0.0112 | Val Acc: 99.65%
# Epoch 30/30
#   Train Loss: 0.0014 | Train Acc: 99.96%
#   Val Loss: 0.0104 | Val Acc: 99.65%

# %% [markdown]
# ### getting the test accuracy for the best learning rate

# %%
print(f"the best learning rate {best_lr}")
logisticRegression = Logistic_Regression_from_scratch()
loader = dl.build_loader(fixed_batch_size)
logisticRegression.train(best_lr, no_epochs, loader['train_loader_linear_filtered'], loader['val_loader_linear_filtered'])
test_model()
# Out:
# the best learning rate 1
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 0.0473 | Train Acc: 98.58%
#   Val Loss: 0.0093 | Val Acc: 99.73%
# Epoch 2/30
#   Train Loss: 0.0117 | Train Acc: 99.63%
#   Val Loss: 0.0064 | Val Acc: 99.77%
# Epoch 3/30
#   Train Loss: 0.0081 | Train Acc: 99.68%
#   Val Loss: 0.0056 | Val Acc: 99.80%
# Epoch 4/30
#   Train Loss: 0.0068 | Train Acc: 99.74%
#   Val Loss: 0.0051 | Val Acc: 99.92%
# Epoch 5/30
#   Train Loss: 0.0059 | Train Acc: 99.78%
#   Val Loss: 0.0053 | Val Acc: 99.88%
# Epoch 6/30
#   Train Loss: 0.0050 | Train Acc: 99.76%
#   Val Loss: 0.0054 | Val Acc: 99.88%
# Epoch 7/30
#   Train Loss: 0.0046 | Train Acc: 99.82%
#   Val Loss: 0.0050 | Val Acc: 99.88%
# Epoch 8/30
#   Train Loss: 0.0039 | Train Acc: 99.84%
#   Val Loss: 0.0049 | Val Acc: 99.88%
# Epoch 9/30
#   Train Loss: 0.0035 | Train Acc: 99.84%
#   Val Loss: 0.0050 | Val Acc: 99.88%
# Epoch 10/30
#   Train Loss: 0.0033 | Train Acc: 99.86%
#   Val Loss: 0.0051 | Val Acc: 99.88%
# Epoch 11/30
#   Train Loss: 0.0030 | Train Acc: 99.89%
#   Val Loss: 0.0050 | Val Acc: 99.88%
# Epoch 12/30
#   Train Loss: 0.0028 | Train Acc: 99.86%
#   Val Loss: 0.0053 | Val Acc: 99.88%
# Epoch 13/30
#   Train Loss: 0.0026 | Train Acc: 99.89%
#   Val Loss: 0.0053 | Val Acc: 99.88%
# Epoch 14/30
#   Train Loss: 0.0023 | Train Acc: 99.91%
#   Val Loss: 0.0051 | Val Acc: 99.88%
# Epoch 15/30
#   Train Loss: 0.0022 | Train Acc: 99.92%
#   Val Loss: 0.0049 | Val Acc: 99.92%
# Epoch 16/30
#   Train Loss: 0.0020 | Train Acc: 99.91%
#   Val Loss: 0.0051 | Val Acc: 99.88%
# Epoch 17/30
#   Train Loss: 0.0019 | Train Acc: 99.95%
#   Val Loss: 0.0053 | Val Acc: 99.88%
# Epoch 18/30
#   Train Loss: 0.0018 | Train Acc: 99.92%
#   Val Loss: 0.0050 | Val Acc: 99.92%
# Epoch 19/30
#   Train Loss: 0.0017 | Train Acc: 99.95%
#   Val Loss: 0.0050 | Val Acc: 99.92%
# Epoch 20/30
#   Train Loss: 0.0016 | Train Acc: 99.95%
#   Val Loss: 0.0049 | Val Acc: 99.92%
# Epoch 21/30
#   Train Loss: 0.0015 | Train Acc: 99.95%
#   Val Loss: 0.0049 | Val Acc: 99.92%
# Epoch 22/30
#   Train Loss: 0.0015 | Train Acc: 99.96%
#   Val Loss: 0.0050 | Val Acc: 99.92%
# Epoch 23/30
#   Train Loss: 0.0013 | Train Acc: 99.96%
#   Val Loss: 0.0048 | Val Acc: 99.92%
# Epoch 24/30
#   Train Loss: 0.0013 | Train Acc: 99.95%
#   Val Loss: 0.0050 | Val Acc: 99.92%
# Epoch 25/30
#   Train Loss: 0.0012 | Train Acc: 99.96%
#   Val Loss: 0.0048 | Val Acc: 99.92%
# Epoch 26/30
#   Train Loss: 0.0013 | Train Acc: 99.97%
#   Val Loss: 0.0048 | Val Acc: 99.92%
# Epoch 27/30
#   Train Loss: 0.0011 | Train Acc: 99.97%
#   Val Loss: 0.0049 | Val Acc: 99.92%
# Epoch 28/30
#   Train Loss: 0.0011 | Train Acc: 99.99%
#   Val Loss: 0.0049 | Val Acc: 99.92%
# Epoch 29/30
#   Train Loss: 0.0010 | Train Acc: 99.99%
#   Val Loss: 0.0048 | Val Acc: 99.92%
# Epoch 30/30
#   Train Loss: 0.0010 | Train Acc: 99.99%
#   Val Loss: 0.0048 | Val Acc: 99.92%
# Average Test Accuracy over all batches: 99.80%
# Confusion Matrix:
# [[1182    3]
#  [   2 1347]]

# %% [markdown]
# ### getting the best batch size

# %%
results_bs = []
fixed_learning_rate = 0.01

print("\nTesting different batch sizes with fixed learning rate (0.01):")
best_val_accuracy_bs = 0
best_bs=None

for bs in batch_sizes:
    print(f"Training with Learning Rate: {fixed_learning_rate}, Batch Size: {bs}")

    logisticRegression = Logistic_Regression_from_scratch()
    loader = dl.build_loader(bs)

    logisticRegression.train(fixed_learning_rate, no_epochs, loader['train_loader_linear_filtered'], loader['val_loader_linear_filtered'])
    plot_acc(f'with batch size of {bs}')
    plot_loss(f'with batch size of {bs}')
    plot_converge(f'with batch size of {bs}')
    current_best_val_accuracy = max(logisticRegression.validation_accuracies)

    if current_best_val_accuracy > best_val_accuracy_bs:
        best_val_accuracy_bs = current_best_val_accuracy
        best_bs=bs
# Out:
# Testing different batch sizes with fixed learning rate (0.01):
# Training with Learning Rate: 0.01, Batch Size: 16
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 0.5313 | Train Acc: 84.85%
#   Val Loss: 0.1181 | Val Acc: 96.07%
# Epoch 2/30
#   Train Loss: 0.0789 | Train Acc: 97.64%
#   Val Loss: 0.0610 | Val Acc: 98.03%
# Epoch 3/30
#   Train Loss: 0.0509 | Train Acc: 98.66%
#   Val Loss: 0.0428 | Val Acc: 98.66%
# Epoch 4/30
#   Train Loss: 0.0398 | Train Acc: 98.92%
#   Val Loss: 0.0335 | Val Acc: 98.90%
# Epoch 5/30
#   Train Loss: 0.0335 | Train Acc: 99.13%
#   Val Loss: 0.0280 | Val Acc: 99.10%
# Epoch 6/30
#   Train Loss: 0.0293 | Train Acc: 99.17%
#   Val Loss: 0.0244 | Val Acc: 99.14%
# Epoch 7/30
#   Train Loss: 0.0264 | Train Acc: 99.24%
#   Val Loss: 0.0218 | Val Acc: 99.25%
# Epoch 8/30
#   Train Loss: 0.0242 | Train Acc: 99.29%
#   Val Loss: 0.0199 | Val Acc: 99.33%
# Epoch 9/30
#   Train Loss: 0.0225 | Train Acc: 99.37%
#   Val Loss: 0.0184 | Val Acc: 99.33%
# Epoch 10/30
#   Train Loss: 0.0211 | Train Acc: 99.43%
#   Val Loss: 0.0172 | Val Acc: 99.41%
# Epoch 11/30
#   Train Loss: 0.0200 | Train Acc: 99.50%
#   Val Loss: 0.0162 | Val Acc: 99.41%
# Epoch 12/30
#   Train Loss: 0.0191 | Train Acc: 99.57%
#   Val Loss: 0.0154 | Val Acc: 99.49%
# Epoch 13/30
#   Train Loss: 0.0183 | Train Acc: 99.59%
#   Val Loss: 0.0147 | Val Acc: 99.49%
# Epoch 14/30
#   Train Loss: 0.0177 | Train Acc: 99.62%
#   Val Loss: 0.0141 | Val Acc: 99.49%
# Epoch 15/30
#   Train Loss: 0.0171 | Train Acc: 99.63%
#   Val Loss: 0.0136 | Val Acc: 99.57%
# Epoch 16/30
#   Train Loss: 0.0166 | Train Acc: 99.66%
#   Val Loss: 0.0131 | Val Acc: 99.57%
# Epoch 17/30
#   Train Loss: 0.0161 | Train Acc: 99.68%
#   Val Loss: 0.0127 | Val Acc: 99.61%
# Epoch 18/30
#   Train Loss: 0.0157 | Train Acc: 99.68%
#   Val Loss: 0.0123 | Val Acc: 99.61%
# Epoch 19/30
#   Train Loss: 0.0153 | Train Acc: 99.68%
#   Val Loss: 0.0120 | Val Acc: 99.65%
# Epoch 20/30
#   Train Loss: 0.0150 | Train Acc: 99.68%
#   Val Loss: 0.0116 | Val Acc: 99.65%
# Epoch 21/30
#   Train Loss: 0.0147 | Train Acc: 99.70%
#   Val Loss: 0.0114 | Val Acc: 99.69%
# Epoch 22/30
#   Train Loss: 0.0144 | Train Acc: 99.70%
#   Val Loss: 0.0111 | Val Acc: 99.65%
# Epoch 23/30
#   Train Loss: 0.0141 | Train Acc: 99.70%
#   Val Loss: 0.0109 | Val Acc: 99.65%
# Epoch 24/30
#   Train Loss: 0.0139 | Train Acc: 99.70%
#   Val Loss: 0.0107 | Val Acc: 99.65%
# Epoch 25/30
#   Train Loss: 0.0136 | Train Acc: 99.71%
#   Val Loss: 0.0104 | Val Acc: 99.65%
# Epoch 26/30
#   Train Loss: 0.0134 | Train Acc: 99.70%
#   Val Loss: 0.0102 | Val Acc: 99.69%
# Epoch 27/30
#   Train Loss: 0.0132 | Train Acc: 99.72%
#   Val Loss: 0.0101 | Val Acc: 99.69%
# Epoch 28/30
#   Train Loss: 0.0130 | Train Acc: 99.72%
#   Val Loss: 0.0099 | Val Acc: 99.72%
# Epoch 29/30
#   Train Loss: 0.0128 | Train Acc: 99.74%
#   Val Loss: 0.0097 | Val Acc: 99.72%
# Epoch 30/30
#   Train Loss: 0.0126 | Train Acc: 99.74%
#   Val Loss: 0.0096 | Val Acc: 99.72%
# Training with Learning Rate: 0.01, Batch Size: 32
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 0.8871 | Train Acc: 78.18%
#   Val Loss: 0.3016 | Val Acc: 90.70%
# Epoch 2/30
#   Train Loss: 0.2277 | Train Acc: 92.48%
#   Val Loss: 0.1389 | Val Acc: 95.94%
# Epoch 3/30
#   Train Loss: 0.1215 | Train Acc: 95.89%
#   Val Loss: 0.0929 | Val Acc: 97.46%
# Epoch 4/30
#   Train Loss: 0.0829 | Train Acc: 97.35%
#   Val Loss: 0.0727 | Val Acc: 98.28%
# Epoch 5/30
#   Train Loss: 0.0643 | Train Acc: 97.88%
#   Val Loss: 0.0614 | Val Acc: 98.52%
# Epoch 6/30
#   Train Loss: 0.0531 | Train Acc: 98.29%
#   Val Loss: 0.0540 | Val Acc: 98.83%
# Epoch 7/30
#   Train Loss: 0.0458 | Train Acc: 98.53%
#   Val Loss: 0.0488 | Val Acc: 98.91%
# Epoch 8/30
#   Train Loss: 0.0409 | Train Acc: 98.71%
#   Val Loss: 0.0448 | Val Acc: 98.95%
# Epoch 9/30
#   Train Loss: 0.0367 | Train Acc: 98.92%
#   Val Loss: 0.0418 | Val Acc: 99.02%
# Epoch 10/30
#   Train Loss: 0.0337 | Train Acc: 98.96%
#   Val Loss: 0.0393 | Val Acc: 99.06%
# Epoch 11/30
#   Train Loss: 0.0319 | Train Acc: 99.06%
#   Val Loss: 0.0372 | Val Acc: 99.06%
# Epoch 12/30
#   Train Loss: 0.0293 | Train Acc: 99.17%
#   Val Loss: 0.0355 | Val Acc: 99.10%
# Epoch 13/30
#   Train Loss: 0.0278 | Train Acc: 99.18%
#   Val Loss: 0.0339 | Val Acc: 99.18%
# Epoch 14/30
#   Train Loss: 0.0261 | Train Acc: 99.21%
#   Val Loss: 0.0326 | Val Acc: 99.26%
# Epoch 15/30
#   Train Loss: 0.0249 | Train Acc: 99.24%
#   Val Loss: 0.0314 | Val Acc: 99.34%
# Epoch 16/30
#   Train Loss: 0.0243 | Train Acc: 99.29%
#   Val Loss: 0.0304 | Val Acc: 99.34%
# Epoch 17/30
#   Train Loss: 0.0229 | Train Acc: 99.33%
#   Val Loss: 0.0294 | Val Acc: 99.34%
# Epoch 18/30
#   Train Loss: 0.0225 | Train Acc: 99.34%
#   Val Loss: 0.0285 | Val Acc: 99.34%
# Epoch 19/30
#   Train Loss: 0.0212 | Train Acc: 99.38%
#   Val Loss: 0.0278 | Val Acc: 99.34%
# Epoch 20/30
#   Train Loss: 0.0205 | Train Acc: 99.42%
#   Val Loss: 0.0271 | Val Acc: 99.38%
# Epoch 21/30
#   Train Loss: 0.0199 | Train Acc: 99.45%
#   Val Loss: 0.0264 | Val Acc: 99.38%
# Epoch 22/30
#   Train Loss: 0.0193 | Train Acc: 99.44%
#   Val Loss: 0.0258 | Val Acc: 99.41%
# Epoch 23/30
#   Train Loss: 0.0188 | Train Acc: 99.45%
#   Val Loss: 0.0253 | Val Acc: 99.41%
# Epoch 24/30
#   Train Loss: 0.0183 | Train Acc: 99.45%
#   Val Loss: 0.0247 | Val Acc: 99.45%
# Epoch 25/30
#   Train Loss: 0.0179 | Train Acc: 99.46%
#   Val Loss: 0.0243 | Val Acc: 99.45%
# Epoch 26/30
#   Train Loss: 0.0174 | Train Acc: 99.47%
#   Val Loss: 0.0238 | Val Acc: 99.45%
# Epoch 27/30
#   Train Loss: 0.0179 | Train Acc: 99.47%
#   Val Loss: 0.0234 | Val Acc: 99.45%
# Epoch 28/30
#   Train Loss: 0.0167 | Train Acc: 99.51%
#   Val Loss: 0.0230 | Val Acc: 99.45%
# Epoch 29/30
#   Train Loss: 0.0163 | Train Acc: 99.51%
#   Val Loss: 0.0226 | Val Acc: 99.49%
# Epoch 30/30
#   Train Loss: 0.0160 | Train Acc: 99.54%
#   Val Loss: 0.0222 | Val Acc: 99.49%
# Training with Learning Rate: 0.01, Batch Size: 64
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 1.1021 | Train Acc: 72.96%
#   Val Loss: 0.5450 | Val Acc: 84.21%
# Epoch 2/30
#   Train Loss: 0.4153 | Train Acc: 87.99%
#   Val Loss: 0.3358 | Val Acc: 91.17%
# Epoch 3/30
#   Train Loss: 0.2849 | Train Acc: 91.93%
#   Val Loss: 0.2522 | Val Acc: 93.52%
# Epoch 4/30
#   Train Loss: 0.2218 | Train Acc: 93.83%
#   Val Loss: 0.2049 | Val Acc: 94.34%
# Epoch 5/30
#   Train Loss: 0.1844 | Train Acc: 94.91%
#   Val Loss: 0.1737 | Val Acc: 95.12%
# Epoch 6/30
#   Train Loss: 0.1584 | Train Acc: 95.68%
#   Val Loss: 0.1517 | Val Acc: 95.86%
# Epoch 7/30
#   Train Loss: 0.1398 | Train Acc: 96.20%
#   Val Loss: 0.1350 | Val Acc: 96.41%
# Epoch 8/30
#   Train Loss: 0.1256 | Train Acc: 96.55%
#   Val Loss: 0.1220 | Val Acc: 96.56%
# Epoch 9/30
#   Train Loss: 0.1145 | Train Acc: 96.83%
#   Val Loss: 0.1115 | Val Acc: 96.76%
# Epoch 10/30
#   Train Loss: 0.1053 | Train Acc: 97.16%
#   Val Loss: 0.1029 | Val Acc: 96.95%
# Epoch 11/30
#   Train Loss: 0.0978 | Train Acc: 97.35%
#   Val Loss: 0.0956 | Val Acc: 97.27%
# Epoch 12/30
#   Train Loss: 0.0916 | Train Acc: 97.54%
#   Val Loss: 0.0894 | Val Acc: 97.46%
# Epoch 13/30
#   Train Loss: 0.0856 | Train Acc: 97.69%
#   Val Loss: 0.0841 | Val Acc: 97.50%
# Epoch 14/30
#   Train Loss: 0.0811 | Train Acc: 97.81%
#   Val Loss: 0.0794 | Val Acc: 97.66%
# Epoch 15/30
#   Train Loss: 0.0767 | Train Acc: 97.89%
#   Val Loss: 0.0753 | Val Acc: 97.77%
# Epoch 16/30
#   Train Loss: 0.0729 | Train Acc: 98.04%
#   Val Loss: 0.0716 | Val Acc: 97.89%
# Epoch 17/30
#   Train Loss: 0.0695 | Train Acc: 98.11%
#   Val Loss: 0.0683 | Val Acc: 97.89%
# Epoch 18/30
#   Train Loss: 0.0670 | Train Acc: 98.15%
#   Val Loss: 0.0653 | Val Acc: 97.89%
# Epoch 19/30
#   Train Loss: 0.0642 | Train Acc: 98.27%
#   Val Loss: 0.0625 | Val Acc: 98.01%
# Epoch 20/30
#   Train Loss: 0.0614 | Train Acc: 98.37%
#   Val Loss: 0.0601 | Val Acc: 98.01%
# Epoch 21/30
#   Train Loss: 0.0594 | Train Acc: 98.39%
#   Val Loss: 0.0578 | Val Acc: 98.05%
# Epoch 22/30
#   Train Loss: 0.0571 | Train Acc: 98.45%
#   Val Loss: 0.0557 | Val Acc: 98.16%
# Epoch 23/30
#   Train Loss: 0.0553 | Train Acc: 98.52%
#   Val Loss: 0.0537 | Val Acc: 98.24%
# Epoch 24/30
#   Train Loss: 0.0536 | Train Acc: 98.60%
#   Val Loss: 0.0519 | Val Acc: 98.28%
# Epoch 25/30
#   Train Loss: 0.0520 | Train Acc: 98.63%
#   Val Loss: 0.0502 | Val Acc: 98.28%
# Epoch 26/30
#   Train Loss: 0.0505 | Train Acc: 98.63%
#   Val Loss: 0.0486 | Val Acc: 98.28%
# Epoch 27/30
#   Train Loss: 0.0494 | Train Acc: 98.66%
#   Val Loss: 0.0471 | Val Acc: 98.44%
# Epoch 28/30
#   Train Loss: 0.0478 | Train Acc: 98.74%
#   Val Loss: 0.0457 | Val Acc: 98.48%
# Epoch 29/30
#   Train Loss: 0.0466 | Train Acc: 98.78%
#   Val Loss: 0.0444 | Val Acc: 98.55%
# Epoch 30/30
#   Train Loss: 0.0454 | Train Acc: 98.79%
#   Val Loss: 0.0432 | Val Acc: 98.59%
# Training with Learning Rate: 0.01, Batch Size: 128
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 1.9398 | Train Acc: 63.79%
#   Val Loss: 0.9157 | Val Acc: 75.37%
# Epoch 2/30
#   Train Loss: 0.6937 | Train Acc: 80.45%
#   Val Loss: 0.5252 | Val Acc: 85.41%
# Epoch 3/30
#   Train Loss: 0.4670 | Train Acc: 86.86%
#   Val Loss: 0.3922 | Val Acc: 90.09%
# Epoch 4/30
#   Train Loss: 0.3646 | Train Acc: 90.01%
#   Val Loss: 0.3200 | Val Acc: 91.89%
# Epoch 5/30
#   Train Loss: 0.3020 | Train Acc: 91.85%
#   Val Loss: 0.2743 | Val Acc: 93.43%
# Epoch 6/30
#   Train Loss: 0.2559 | Train Acc: 93.05%
#   Val Loss: 0.2426 | Val Acc: 93.97%
# Epoch 7/30
#   Train Loss: 0.2251 | Train Acc: 93.79%
#   Val Loss: 0.2192 | Val Acc: 94.56%
# Epoch 8/30
#   Train Loss: 0.2028 | Train Acc: 94.40%
#   Val Loss: 0.2010 | Val Acc: 95.18%
# Epoch 9/30
#   Train Loss: 0.1846 | Train Acc: 94.98%
#   Val Loss: 0.1865 | Val Acc: 95.34%
# Epoch 10/30
#   Train Loss: 0.1697 | Train Acc: 95.42%
#   Val Loss: 0.1748 | Val Acc: 95.73%
# Epoch 11/30
#   Train Loss: 0.1617 | Train Acc: 95.71%
#   Val Loss: 0.1647 | Val Acc: 95.93%
# Epoch 12/30
#   Train Loss: 0.1483 | Train Acc: 95.95%
#   Val Loss: 0.1562 | Val Acc: 96.04%
# Epoch 13/30
#   Train Loss: 0.1393 | Train Acc: 96.29%
#   Val Loss: 0.1489 | Val Acc: 96.28%
# Epoch 14/30
#   Train Loss: 0.1321 | Train Acc: 96.49%
#   Val Loss: 0.1424 | Val Acc: 96.36%
# Epoch 15/30
#   Train Loss: 0.1245 | Train Acc: 96.76%
#   Val Loss: 0.1368 | Val Acc: 96.55%
# Epoch 16/30
#   Train Loss: 0.1228 | Train Acc: 96.79%
#   Val Loss: 0.1317 | Val Acc: 96.83%
# Epoch 17/30
#   Train Loss: 0.1138 | Train Acc: 96.95%
#   Val Loss: 0.1272 | Val Acc: 96.86%
# Epoch 18/30
#   Train Loss: 0.1105 | Train Acc: 97.00%
#   Val Loss: 0.1230 | Val Acc: 97.02%
# Epoch 19/30
#   Train Loss: 0.1057 | Train Acc: 97.15%
#   Val Loss: 0.1192 | Val Acc: 97.22%
# Epoch 20/30
#   Train Loss: 0.1016 | Train Acc: 97.25%
#   Val Loss: 0.1158 | Val Acc: 97.33%
# Epoch 21/30
#   Train Loss: 0.0989 | Train Acc: 97.32%
#   Val Loss: 0.1126 | Val Acc: 97.37%
# Epoch 22/30
#   Train Loss: 0.0945 | Train Acc: 97.43%
#   Val Loss: 0.1097 | Val Acc: 97.41%
# Epoch 23/30
#   Train Loss: 0.0918 | Train Acc: 97.47%
#   Val Loss: 0.1070 | Val Acc: 97.41%
# Epoch 24/30
#   Train Loss: 0.0904 | Train Acc: 97.50%
#   Val Loss: 0.1045 | Val Acc: 97.41%
# Epoch 25/30
#   Train Loss: 0.0869 | Train Acc: 97.57%
#   Val Loss: 0.1021 | Val Acc: 97.45%
# Epoch 26/30
#   Train Loss: 0.0841 | Train Acc: 97.63%
#   Val Loss: 0.0999 | Val Acc: 97.53%
# Epoch 27/30
#   Train Loss: 0.0823 | Train Acc: 97.66%
#   Val Loss: 0.0979 | Val Acc: 97.57%
# Epoch 28/30
#   Train Loss: 0.0801 | Train Acc: 97.76%
#   Val Loss: 0.0959 | Val Acc: 97.61%
# Epoch 29/30
#   Train Loss: 0.0784 | Train Acc: 97.82%
#   Val Loss: 0.0940 | Val Acc: 97.65%
# Epoch 30/30
#   Train Loss: 0.0774 | Train Acc: 97.87%
#   Val Loss: 0.0923 | Val Acc: 97.65%

# %% [markdown]
# ### calculating the test accuracy for the best batch size

# %%
print(f"the best batch size {best_bs}")

logisticRegression = Logistic_Regression_from_scratch()
loader = dl.build_loader(best_bs)
logisticRegression.train(fixed_learning_rate, no_epochs, loader['train_loader_linear_filtered'], loader['val_loader_linear_filtered'])
test_model()
# Out:
# the best batch size 16
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 0.6490 | Train Acc: 87.83%
#   Val Loss: 0.1863 | Val Acc: 95.17%
# Epoch 2/30
#   Train Loss: 0.1182 | Train Acc: 96.75%
#   Val Loss: 0.1121 | Val Acc: 97.09%
# Epoch 3/30
#   Train Loss: 0.0796 | Train Acc: 97.79%
#   Val Loss: 0.0846 | Val Acc: 97.72%
# Epoch 4/30
#   Train Loss: 0.0626 | Train Acc: 98.34%
#   Val Loss: 0.0692 | Val Acc: 98.15%
# Epoch 5/30
#   Train Loss: 0.0521 | Train Acc: 98.49%
#   Val Loss: 0.0587 | Val Acc: 98.31%
# Epoch 6/30
#   Train Loss: 0.0449 | Train Acc: 98.59%
#   Val Loss: 0.0512 | Val Acc: 98.47%
# Epoch 7/30
#   Train Loss: 0.0396 | Train Acc: 98.72%
#   Val Loss: 0.0454 | Val Acc: 98.55%
# Epoch 8/30
#   Train Loss: 0.0353 | Train Acc: 98.84%
#   Val Loss: 0.0408 | Val Acc: 98.66%
# Epoch 9/30
#   Train Loss: 0.0319 | Train Acc: 99.00%
#   Val Loss: 0.0371 | Val Acc: 98.90%
# Epoch 10/30
#   Train Loss: 0.0292 | Train Acc: 99.16%
#   Val Loss: 0.0341 | Val Acc: 98.94%
# Epoch 11/30
#   Train Loss: 0.0270 | Train Acc: 99.24%
#   Val Loss: 0.0316 | Val Acc: 98.98%
# Epoch 12/30
#   Train Loss: 0.0251 | Train Acc: 99.29%
#   Val Loss: 0.0295 | Val Acc: 98.98%
# Epoch 13/30
#   Train Loss: 0.0235 | Train Acc: 99.30%
#   Val Loss: 0.0277 | Val Acc: 98.98%
# Epoch 14/30
#   Train Loss: 0.0222 | Train Acc: 99.32%
#   Val Loss: 0.0261 | Val Acc: 98.98%
# Epoch 15/30
#   Train Loss: 0.0211 | Train Acc: 99.38%
#   Val Loss: 0.0247 | Val Acc: 99.06%
# Epoch 16/30
#   Train Loss: 0.0201 | Train Acc: 99.41%
#   Val Loss: 0.0235 | Val Acc: 99.06%
# Epoch 17/30
#   Train Loss: 0.0192 | Train Acc: 99.43%
#   Val Loss: 0.0224 | Val Acc: 99.14%
# Epoch 18/30
#   Train Loss: 0.0184 | Train Acc: 99.43%
#   Val Loss: 0.0214 | Val Acc: 99.14%
# Epoch 19/30
#   Train Loss: 0.0177 | Train Acc: 99.43%
#   Val Loss: 0.0206 | Val Acc: 99.21%
# Epoch 20/30
#   Train Loss: 0.0171 | Train Acc: 99.46%
#   Val Loss: 0.0198 | Val Acc: 99.25%
# Epoch 21/30
#   Train Loss: 0.0165 | Train Acc: 99.45%
#   Val Loss: 0.0191 | Val Acc: 99.25%
# Epoch 22/30
#   Train Loss: 0.0160 | Train Acc: 99.51%
#   Val Loss: 0.0185 | Val Acc: 99.29%
# Epoch 23/30
#   Train Loss: 0.0155 | Train Acc: 99.54%
#   Val Loss: 0.0179 | Val Acc: 99.29%
# Epoch 24/30
#   Train Loss: 0.0151 | Train Acc: 99.54%
#   Val Loss: 0.0173 | Val Acc: 99.29%
# Epoch 25/30
#   Train Loss: 0.0147 | Train Acc: 99.54%
#   Val Loss: 0.0168 | Val Acc: 99.33%
# Epoch 26/30
#   Train Loss: 0.0143 | Train Acc: 99.55%
#   Val Loss: 0.0163 | Val Acc: 99.33%
# Epoch 27/30
#   Train Loss: 0.0140 | Train Acc: 99.55%
#   Val Loss: 0.0159 | Val Acc: 99.37%
# Epoch 28/30
#   Train Loss: 0.0136 | Train Acc: 99.57%
#   Val Loss: 0.0156 | Val Acc: 99.37%
# Epoch 29/30
#   Train Loss: 0.0133 | Train Acc: 99.58%
#   Val Loss: 0.0153 | Val Acc: 99.37%
# Epoch 30/30
#   Train Loss: 0.0131 | Train Acc: 99.61%
#   Val Loss: 0.0149 | Val Acc: 99.37%
# Average Test Accuracy over all batches: 99.17%
# Confusion Matrix:
# [[1182    3]
#  [  18 1331]]

# %% [markdown]
# ### combining best learning rate with the best batch size

# %%
import time

print(f"the best batch size {best_bs}")
print(f"the best learning rate {best_lr}")
logisticRegression = Logistic_Regression_from_scratch()
loader = dl.build_loader(best_bs)

start_time = time.time()
logisticRegression.train(best_lr, no_epochs, loader['train_loader_linear_filtered'], loader['val_loader_linear_filtered'])
end_time = time.time()
print(f"Training time: {end_time - start_time:.2f} seconds")

test_model()
# Out:
# the best batch size 16
# the best learning rate 1
# Number of training samples: 60000
# Shape of x_train: torch.Size([36000, 28, 28]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 28, 28]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 28, 28]), y_test: torch.Size([12000])
# After filtering for classes 0 and 1:
# Shape of x_train_filtered: torch.Size([7599, 784]), y_train_filtered: torch.Size([7599])
# Shape of x_val_filtered: torch.Size([2532, 784]), y_val_filtered: torch.Size([2532])
# Shape of x_test_filtered: torch.Size([2534, 784]), y_test_filtered: torch.Size([2534])
# ---------
# Shape of x_train: torch.Size([36000, 784]), y_train: torch.Size([36000])
# Shape of x_val: torch.Size([12000, 784]), y_val: torch.Size([12000])
# Shape of x_test: torch.Size([12000, 784]), y_test: torch.Size([12000])
# Epoch 1/30
#   Train Loss: 0.0315 | Train Acc: 99.38%
#   Val Loss: 0.0149 | Val Acc: 99.69%
# Epoch 2/30
#   Train Loss: 0.0071 | Train Acc: 99.79%
#   Val Loss: 0.0137 | Val Acc: 99.69%
# Epoch 3/30
#   Train Loss: 0.0050 | Train Acc: 99.84%
#   Val Loss: 0.0060 | Val Acc: 99.84%
# Epoch 4/30
#   Train Loss: 0.0051 | Train Acc: 99.87%
#   Val Loss: 0.0104 | Val Acc: 99.76%
# Epoch 5/30
#   Train Loss: 0.0034 | Train Acc: 99.93%
#   Val Loss: 0.0160 | Val Acc: 99.65%
# Epoch 6/30
#   Train Loss: 0.0026 | Train Acc: 99.92%
#   Val Loss: 0.0115 | Val Acc: 99.76%
# Epoch 7/30
#   Train Loss: 0.0028 | Train Acc: 99.92%
#   Val Loss: 0.0131 | Val Acc: 99.69%
# Epoch 8/30
#   Train Loss: 0.0024 | Train Acc: 99.89%
#   Val Loss: 0.0091 | Val Acc: 99.76%
# Epoch 9/30
#   Train Loss: 0.0019 | Train Acc: 99.93%
#   Val Loss: 0.0122 | Val Acc: 99.69%
# Epoch 10/30
#   Train Loss: 0.0016 | Train Acc: 99.96%
#   Val Loss: 0.0109 | Val Acc: 99.72%
# Epoch 11/30
#   Train Loss: 0.0011 | Train Acc: 99.97%
#   Val Loss: 0.0082 | Val Acc: 99.80%
# Epoch 12/30
#   Train Loss: 0.0009 | Train Acc: 99.99%
#   Val Loss: 0.0090 | Val Acc: 99.76%
# Epoch 13/30
#   Train Loss: 0.0006 | Train Acc: 99.99%
#   Val Loss: 0.0079 | Val Acc: 99.80%
# Epoch 14/30
#   Train Loss: 0.0006 | Train Acc: 99.99%
#   Val Loss: 0.0082 | Val Acc: 99.80%
# Epoch 15/30
#   Train Loss: 0.0005 | Train Acc: 100.00%
#   Val Loss: 0.0080 | Val Acc: 99.80%
# Epoch 16/30
#   Train Loss: 0.0004 | Train Acc: 100.00%
#   Val Loss: 0.0085 | Val Acc: 99.80%
# Epoch 17/30
#   Train Loss: 0.0004 | Train Acc: 100.00%
#   Val Loss: 0.0088 | Val Acc: 99.76%
# Epoch 18/30
#   Train Loss: 0.0003 | Train Acc: 100.00%
#   Val Loss: 0.0096 | Val Acc: 99.69%
# Epoch 19/30
#   Train Loss: 0.0003 | Train Acc: 100.00%
#   Val Loss: 0.0095 | Val Acc: 99.69%
# Epoch 20/30
#   Train Loss: 0.0003 | Train Acc: 100.00%
#   Val Loss: 0.0088 | Val Acc: 99.69%
# Epoch 21/30
#   Train Loss: 0.0003 | Train Acc: 100.00%
#   Val Loss: 0.0089 | Val Acc: 99.69%
# Epoch 22/30
#   Train Loss: 0.0003 | Train Acc: 100.00%
#   Val Loss: 0.0092 | Val Acc: 99.69%
# Epoch 23/30
#   Train Loss: 0.0003 | Train Acc: 100.00%
#   Val Loss: 0.0088 | Val Acc: 99.72%
# Epoch 24/30
#   Train Loss: 0.0002 | Train Acc: 100.00%
#   Val Loss: 0.0088 | Val Acc: 99.72%
# Epoch 25/30
#   Train Loss: 0.0002 | Train Acc: 100.00%
#   Val Loss: 0.0088 | Val Acc: 99.72%
# Epoch 26/30
#   Train Loss: 0.0002 | Train Acc: 100.00%
#   Val Loss: 0.0092 | Val Acc: 99.69%
# Epoch 27/30
#   Train Loss: 0.0002 | Train Acc: 100.00%
#   Val Loss: 0.0086 | Val Acc: 99.80%
# Epoch 28/30
#   Train Loss: 0.0002 | Train Acc: 100.00%
#   Val Loss: 0.0087 | Val Acc: 99.76%
# Epoch 29/30
#   Train Loss: 0.0002 | Train Acc: 100.00%
#   Val Loss: 0.0083 | Val Acc: 99.80%
# Epoch 30/30
#   Train Loss: 0.0002 | Train Acc: 100.00%
#   Val Loss: 0.0086 | Val Acc: 99.76%
# Training time: 14.00 seconds
# Average Test Accuracy over all batches: 99.76%
# Confusion Matrix:
# [[1183    2]
#  [   4 1345]]
